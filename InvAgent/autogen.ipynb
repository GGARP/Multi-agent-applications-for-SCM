# %% [markdown]
# # AutoGen for Supply Chain Management

# %%
import os
import re
import sys
import time
import numpy as np
from typing import List
from tqdm.notebook import tqdm
from autogen import ConversableAgent
from env import env_creator
from config import env_configs

np.random.seed(42)
# Out:
# Variable demand for t=0: 4

# %%
for name, config in env_configs.items():
    # Evaluate demand function at a specific time, say t=0.
    demand_value = config['demand_fn'](0)
    print(f"{name} demand for t=0: {demand_value}")
# Out:
# two_agent demand for t=0: 4
# constant_demand demand for t=0: 4
# variable_demand demand for t=0: 3
# larger_demand demand for t=0: 7
# seasonal_demand demand for t=0: 4
# normal_demand demand for t=0: 1
# increasing_demand demand for t=0: 5
# cyclical_demand demand for t=0: 5
# demand_shock demand for t=0: 5
# stochastic_demand demand for t=0: 0

# %%
os.environ["DEEPSEEK_API_KEY"] = "YOUR_DEEPSEEK_KEY"
llm_config = {
    "model": "deepseek-chat",  # Replace with the correct DeepSeek model name
    "api_key": os.getenv("DEEPSEEK_API_KEY"),  # Fetch the API key from environment variables
    "base_url": "https://api.deepseek.com"   # DeepSeek's API endpoint
}

# %%
os.environ["OPENAI_API_KEY"] = "YOUR_OPENAI_KEY"

# %%
llm_config = {"model": "gpt-4o-mini", "api_key": os.getenv('OPENAI_API_KEY')}

# %% [markdown]
# ## Creating the Environment

# %%
env_config_name ="demand_shock"
env_config = env_configs[env_config_name]
im_env = env_creator(env_config)

# %% [markdown]
# ## Getting Descriptions

# %%
def get_state_description(state):
    return (
        f" - Lead Time: {state['lead_time']} round(s)\n"
        f" - Inventory Level: {state['inventory']} unit(s)\n"
        f" - Current Backlog (you owing to the downstream): {state['backlog']} unit(s)\n"
        f" - Upstream Backlog (your upstream owing to you): {state['upstream_backlog']} unit(s)\n"
        f" - Previous Sales (in the recent round(s), from old to new): {state['sales']}\n"
        f" - Arriving Deliveries (in this and the next round(s), from near to far): {state['deliveries'][-state['lead_time']:]}"
    )

# %%
def get_demand_description(env_config_name):
    if env_config_name == "constant_demand":
        return "The expected demand at the retailer (stage 1) is a constant 4 units for all 12 rounds."
    elif env_config_name == "variable_demand":
        return "The expected demand at the retailer (stage 1) is a discrete uniform distribution U{0, 4} for all 12 rounds."
    elif env_config_name == "larger_demand":
        return "The expected demand at the retailer (stage 1) is a discrete uniform distribution U{0, 8} for all 12 rounds."
    elif env_config_name == "seasonal_demand":
        return "The expected demand at the retailer (stage 1) is a discrete uniform distribution U{0, 4} for the first 4 rounds, " \
            "and a discrete uniform distribution U{5, 8} for the last 8 rounds."
    elif env_config_name == "normal_demand":
        return "The expected demand at the retailer (stage 1) is a normal distribution N(4, 2^2), " \
            "truncated at 0, for all 12 rounds."
    elif env_config_name == "increasing_demand":
        return "The expected demand at the retailer (stage 1) is a linearly increasing demand by starting with an initial value 6, " \
            "and growing by 1 unit every period"
    elif env_config_name == "stochastic_demand":
        return "The expected demand at the retailer (stage 1) is an Integer-Valued Autoregressive INAR(1) process with a thinning probability of 0.5, meaning 50% of the previous period's " \
            "demand carries over. New demand is added as Poisson arrivals with a mean of 2, ensuring the overall demand remains an integer count."
    elif env_config_name == "cyclical_demand":
        return "The expected demand at the retailer (stage 1) is computed as a seasonal sine wave—with a 12-round period, a 5-unit amplitude, " \
            "and a 6-unit upward shift—whose value is rounded to yield an integer."
    elif env_config_name == "demand_shock":
        return "The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10," \
            "capturing a temporary demand shock."
    else:
        raise KeyError(f"Error: {env_config_name} not implemented.")

print(get_demand_description(env_config_name))
# Out:
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock.

# %% [markdown]
# ## Creating Agents

# %%
user_proxy = ConversableAgent(
    name="UserProxy",
    llm_config=False,
    human_input_mode="NEVER",
)

# %%
def create_agents(stage_names: List[str], llm_config) -> List[ConversableAgent]:
    agents = []
    num_stages = len(stage_names)
    
    for stage, stage_name in enumerate(stage_names):
        agent = ConversableAgent(
            name=f"{stage_name.capitalize()}_Agent",
            system_message=f"You play a crucial role in a {num_stages}-stage supply chain as the stage {stage + 1} ({stage_name}). "
                "Your goal is to minimize the total cost by managing inventory and orders effectively.",
            llm_config=llm_config,
            code_execution_config=False,
            human_input_mode="NEVER",
        )
        agents.append(agent)
        
    return agents

stage_agents = create_agents(env_config["stage_names"], llm_config)
# Out:
# [autogen.oai.client: 03-29 12:16:49] {129} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
# [autogen.oai.client: 03-29 12:16:49] {129} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
# [autogen.oai.client: 03-29 12:16:49] {129} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
# [autogen.oai.client: 03-29 12:16:49] {129} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.

# %% [markdown]
# ## Running Simulations

# %%
def run_simulation(env_config_name, im_env, user_proxy, stage_agents):
    demand_description = get_demand_description(env_config_name) 
    all_state_dicts = {}
    all_action_dicts = {}
    all_reward_dicts = {}
    episode_reward = 0
    api_cost = 0
    im_env.reset()
    
    if env_config_name == 'stochastic_demand':
        print("Generating a new stochastic demand series...")  
        env_config["demand_fn"].generate_new_series()  # Reset demand for a new episode
    
    
    for period in range(im_env.num_periods):
        state_dict = im_env.parse_state(im_env.state_dict)
        all_state_dicts[period] = state_dict
        action_dict = {}
        
        for stage in range(im_env.num_stages):
            stage_state = state_dict[f'stage_{stage}']
            
            if stage != 0:
                downstream_order = f"Your downstream order from the stage {stage} for this round is {action_dict[f'stage_{stage - 1}']}. "
            else:
                downstream_order = ""

            message = (
                f"Now this is the round {period + 1}, "
                f"and you are at the stage {stage + 1} of {im_env.num_stages} in the supply chain. "
                f"Given your current state:\n{get_state_description(stage_state)}\n\n"
                f"{demand_description} {downstream_order}"
                "What is your action (order quantity) for this round?\n\n"
                "Please state your reason in 1-2 sentences first "
                "and then provide your action as a non-negative integer within brackets (e.g. [0])."
            )

            chat_result = user_proxy.initiate_chat(
                stage_agents[stage],
                message=message,
                summary_method="last_msg",
                max_turns=1,
                clear_history=False,
            )
            chat_summary = chat_result.summary
            api_cost += chat_result.cost['usage_including_cached_inference']['total_cost']

            match = re.search(r'\[(\d+)\]', chat_summary)
            if match:
                stage_action = int(match.group(1))
            else:
                stage_action = 0
            action_dict[f'stage_{stage}'] = stage_action
            
        next_states, rewards, terminations, truncations, infos = im_env.step(action_dict)
        next_state_dict = im_env.parse_state(next_states)
        all_state_dicts[period + 1] = next_state_dict
        all_action_dicts[period + 1] = action_dict
        all_reward_dicts[period + 1] = rewards
        episode_reward += sum(rewards.values())
        print(
            f"period = {period}, action_dict = {action_dict}, rewards = {rewards}, episode_reward = {episode_reward}, " \
            f"api_cost = {api_cost}")
        print('=' * 80)

    return episode_reward

# %%
from tqdm import tqdm
import numpy as np

rewards = []

for _ in tqdm(range(1)):


    stage_agents = create_agents(env_config["stage_names"], llm_config)
    reward = run_simulation(env_config_name, im_env, user_proxy, stage_agents)
    rewards.append(reward)
    print(f"rewards = {rewards}")

mean_reward = np.mean(rewards)
std_reward = np.std(rewards)

print(f"Rewards: {rewards}")
print(f"Mean Episode Reward: {mean_reward}")
print(f"Standard Deviation of Episode Reward: {std_reward}")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# [autogen.oai.client: 03-29 12:16:50] {129} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
# [autogen.oai.client: 03-29 12:16:50] {129} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
# [autogen.oai.client: 03-29 12:16:50] {129} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
# [autogen.oai.client: 03-29 12:16:50] {129} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
# UserProxy (to Retailer_Agent):
#
# Now this is the round 1, and you are at the stage 1 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 12 unit(s)
#  - Current Backlog (you owing to the downstream): 0 unit(s)
#  - Upstream Backlog (your upstream owing to you): 0 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [0, 0]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [0, 0]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
#
# --------------------------------------------------------------------------------
# Retailer_Agent (to UserProxy):
#
# Given the expected demand of 5 units plus a temporary jump to 13 units during rounds 8 to 10, I should order enough units to cover both the normal demand and prepare for the demand increase to ensure I can meet customer needs without running out of stock. Since I currently have 12 units in inventory and will face a significant increase in demand, I will order 1 additional unit to maintain a buffer.
#
# Therefore, my action is to order [1].
#
# --------------------------------------------------------------------------------
# UserProxy (to Wholesaler_Agent):
#
# Now this is the round 1, and you are at the stage 2 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 12 unit(s)
#  - Current Backlog (you owing to the downstream): 0 unit(s)
#  - Upstream Backlog (your upstream owing to you): 0 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [0, 0]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [0, 0]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. Your downstream order from the stage 1 for this round is 1. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
#
# --------------------------------------------------------------------------------
# Wholesaler_Agent (to UserProxy):
#
# Given the expected demand increase at the retailer to 13 units for the next few rounds and my current inventory level of 12 units, I should order a quantity that balances the expected demand while considering lead time. Since I have a backlog of 1 unit from the downstream order and foresee increased demand, I will place an order for 2 units to prepare for the anticipated demand shock.
#
# My action is [2].
#
# --------------------------------------------------------------------------------
# UserProxy (to Distributor_Agent):
#
# Now this is the round 1, and you are at the stage 3 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 12 unit(s)
#  - Current Backlog (you owing to the downstream): 0 unit(s)
#  - Upstream Backlog (your upstream owing to you): 0 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [0, 0]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [0, 0]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. Your downstream order from the stage 2 for this round is 2. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
#
# --------------------------------------------------------------------------------
# Distributor_Agent (to UserProxy):
#
# Given the expected increase in demand due to the temporary demand shock, I need to prepare for a higher sales volume while also taking into account the 2-round lead time. Since my current inventory level is 12 units and I have an order of 2 units inbound, I will place an order for additional stock to ensure I can meet the anticipated demand in the upcoming rounds, factoring in the expected demand increase to avoid a backlog.
#
# To cover the demand of 13 units in period 8 while considering my incoming and current inventory, I will order 5 additional units this round.
#
# Action: [5]
#
# --------------------------------------------------------------------------------
# UserProxy (to Manufacturer_Agent):
#
# Now this is the round 1, and you are at the stage 4 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 12 unit(s)
#  - Current Backlog (you owing to the downstream): 0 unit(s)
#  - Upstream Backlog (your upstream owing to you): 0 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [0, 0]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [0, 0]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. Your downstream order from the stage 3 for this round is 5. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
#
# --------------------------------------------------------------------------------
#   0%|          | 0/1 [00:08<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 10
#       6 for _ in tqdm(range(1)):
#       9     stage_agents = create_agents(env_config["stage_names"], llm_config)
# ---> 10     reward = run_simulation(env_config_name, im_env, user_proxy, stage_agents)
#      11     rewards.append(reward)
#      12     print(f"rewards = {rewards}")
#
# Cell In[11], line 38, in run_simulation(env_config_name, im_env, user_proxy, stage_agents)
#      26     downstream_order = ""
#      28 message = (
#      29     f"Now this is the round {period + 1}, "
#      30     f"and you are at the stage {stage + 1} of {im_env.num_stages} in the supply chain. "
#    (...)
#      35     "and then provide your action as a non-negative integer within brackets (e.g. [0])."
#      36 )
# ---> 38 chat_result = user_proxy.initiate_chat(
#      39     stage_agents[stage],
#      40     message=message,
#      41     summary_method="last_msg",
#      42     max_turns=1,
#      43     clear_history=False,
#      44 )
#      45 chat_summary = chat_result.summary
#      46 api_cost += chat_result.cost['usage_including_cached_inference']['total_cost']
#
# File ~\AppData\Roaming\Python\Python311\site-packages\autogen\agentchat\conversable_agent.py:1011, in ConversableAgent.initiate_chat(self, recipient, clear_history, silent, cache, max_turns, summary_method, summary_args, message, **kwargs)
#    1009         if msg2send is None:
#    1010             break
# -> 1011         self.send(msg2send, recipient, request_reply=True, silent=silent)
#    1012 else:
#    1013     self._prepare_chat(recipient, clear_history)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\autogen\agentchat\conversable_agent.py:655, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#     653 valid = self._append_oai_message(message, "assistant", recipient)
#     654 if valid:
# --> 655     recipient.receive(message, self, request_reply, silent)
#     656 else:
#     657     raise ValueError(
#     658         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#     659     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\autogen\agentchat\conversable_agent.py:818, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#     816 if request_reply is False or request_reply is None and self.reply_at_receive[sender] is False:
#     817     return
# --> 818 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#     819 if reply is not None:
#     820     self.send(reply, sender, silent=silent)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\autogen\agentchat\conversable_agent.py:1974, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    1972     continue
#    1973 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 1974     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    1975     if logging_enabled():
#    1976         log_event(
#    1977             self,
#    1978             "reply_func_executed",
#    (...)
#    1982             reply=reply,
#    1983         )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\autogen\agentchat\conversable_agent.py:1340, in ConversableAgent.generate_oai_reply(self, messages, sender, config)
#    1338 if messages is None:
#    1339     messages = self._oai_messages[sender]
# -> 1340 extracted_response = self._generate_oai_reply_from_client(
#    1341     client, self._oai_system_message + messages, self.client_cache
#    1342 )
#    1343 return (False, None) if extracted_response is None else (True, extracted_response)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\autogen\agentchat\conversable_agent.py:1359, in ConversableAgent._generate_oai_reply_from_client(self, llm_client, messages, cache)
#    1356         all_messages.append(message)
#    1358 # TODO: #1143 handle token limit exceeded error
# -> 1359 response = llm_client.create(
#    1360     context=messages[-1].pop("context", None),
#    1361     messages=all_messages,
#    1362     cache=cache,
#    1363 )
#    1364 extracted_response = llm_client.extract_text_or_completion_object(response)[0]
#    1366 if extracted_response is None:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\autogen\oai\client.py:639, in OpenAIWrapper.create(self, **config)
#     637 try:
#     638     request_ts = get_current_ts()
# --> 639     response = client.create(params)
#     640 except APITimeoutError as err:
#     641     logger.debug(f"config {i} timed out", exc_info=True)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\autogen\oai\client.py:285, in OpenAIClient.create(self, params)
#     283     params = params.copy()
#     284     params["stream"] = False
# --> 285     response = completions.create(**params)
#     287 return response
#
# File ~\anaconda3\envs\gpu_env\Lib\site-packages\openai\_utils\_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\gpu_env\Lib\site-packages\openai\resources\chat\completions\completions.py:914, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     871 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     872 def create(
#     873     self,
#    (...)
#     911     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     912 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     913     validate_response_format(response_format)
# --> 914     return self._post(
#     915         "/chat/completions",
#     916         body=maybe_transform(
#     917             {
#     918                 "messages": messages,
#     919                 "model": model,
#     920                 "audio": audio,
#     921                 "frequency_penalty": frequency_penalty,
#     922                 "function_call": function_call,
#     923                 "functions": functions,
#     924                 "logit_bias": logit_bias,
#     925                 "logprobs": logprobs,
#     926                 "max_completion_tokens": max_completion_tokens,
#     927                 "max_tokens": max_tokens,
#     928                 "metadata": metadata,
#     929                 "modalities": modalities,
#     930                 "n": n,
#     931                 "parallel_tool_calls": parallel_tool_calls,
#     932                 "prediction": prediction,
#     933                 "presence_penalty": presence_penalty,
#     934                 "reasoning_effort": reasoning_effort,
#     935                 "response_format": response_format,
#     936                 "seed": seed,
#     937                 "service_tier": service_tier,
#     938                 "stop": stop,
#     939                 "store": store,
#     940                 "stream": stream,
#     941                 "stream_options": stream_options,
#     942                 "temperature": temperature,
#     943                 "tool_choice": tool_choice,
#     944                 "tools": tools,
#     945                 "top_logprobs": top_logprobs,
#     946                 "top_p": top_p,
#     947                 "user": user,
#     948                 "web_search_options": web_search_options,
#     949             },
#     950             completion_create_params.CompletionCreateParams,
#     951         ),
#     952         options=make_request_options(
#     953             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     954         ),
#     955         cast_to=ChatCompletion,
#     956         stream=stream or False,
#     957         stream_cls=Stream[ChatCompletionChunk],
#     958     )
#
# File ~\anaconda3\envs\gpu_env\Lib\site-packages\openai\_base_client.py:1242, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1228 def post(
#    1229     self,
#    1230     path: str,
#    (...)
#    1237     stream_cls: type[_StreamT] | None = None,
#    1238 ) -> ResponseT | _StreamT:
#    1239     opts = FinalRequestOptions.construct(
#    1240         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1241     )
# -> 1242     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\anaconda3\envs\gpu_env\Lib\site-packages\openai\_base_client.py:919, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     916 else:
#     917     retries_taken = 0
# --> 919 return self._request(
#     920     cast_to=cast_to,
#     921     options=options,
#     922     stream=stream,
#     923     stream_cls=stream_cls,
#     924     retries_taken=retries_taken,
#     925 )
#
# File ~\anaconda3\envs\gpu_env\Lib\site-packages\openai\_base_client.py:955, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     952 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     954 try:
# --> 955     response = self._client.send(
#     956         request,
#     957         stream=stream or self._should_stream_response_body(request=request),
#     958         **kwargs,
#     959     )
#     960 except httpx.TimeoutException as err:
#     961     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~\anaconda3\envs\gpu_env\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~\anaconda3\envs\gpu_env\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~\anaconda3\envs\gpu_env\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~\anaconda3\envs\gpu_env\Lib\site-packages\httpx\_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File ~\anaconda3\envs\gpu_env\Lib\site-packages\httpx\_transports\default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File ~\anaconda3\envs\gpu_env\Lib\site-packages\httpcore\_sync\connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     266     with ShieldCancellation():
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#     270     break
#
# File ~\anaconda3\envs\gpu_env\Lib\site-packages\httpcore\_sync\connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     248         raise exc
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#     260     with self._pool_lock:
#     261         # Maintain our position in the request queue, but reset the
#     262         # status so that the request becomes queued again.
#
# File ~\anaconda3\envs\gpu_env\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     elif not self._connection.is_available():
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~\anaconda3\envs\gpu_env\Lib\site-packages\httpcore\_sync\http11.py:133, in HTTP11Connection.handle_request(self, request)
#     131     with Trace("response_closed", logger, request) as trace:
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~\anaconda3\envs\gpu_env\Lib\site-packages\httpcore\_sync\http11.py:111, in HTTP11Connection.handle_request(self, request)
#     101     pass
#     103 with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#     119 return Response(
#     120     status=status,
#     121     headers=headers,
#    (...)
#     127     },
#     128 )
#
# File ~\anaconda3\envs\gpu_env\Lib\site-packages\httpcore\_sync\http11.py:176, in HTTP11Connection._receive_response_headers(self, request)
#     173 timeout = timeouts.get("read", None)
#     175 while True:
# --> 176     event = self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#     178         break
#
# File ~\anaconda3\envs\gpu_env\Lib\site-packages\httpcore\_sync\http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     209     event = self._h11_state.next_event()
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#     224     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~\anaconda3\envs\gpu_env\Lib\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File ~\anaconda3\envs\gpu_env\Lib\ssl.py:1295, in SSLSocket.recv(self, buflen, flags)
#    1291     if flags != 0:
#    1292         raise ValueError(
#    1293             "non-zero flags not allowed in calls to recv() on %s" %
#    1294             self.__class__)
# -> 1295     return self.read(buflen)
#    1296 else:
#    1297     return super().recv(buflen, flags)
#
# File ~\anaconda3\envs\gpu_env\Lib\ssl.py:1168, in SSLSocket.read(self, len, buffer)
#    1166         return self._sslobj.read(len, buffer)
#    1167     else:
# -> 1168         return self._sslobj.read(len)
#    1169 except SSLError as x:
#    1170     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
# --------------------------------------------------------------------------------
# Retailer_Agent (to UserProxy):
#
# To prepare for the demand shock starting in round 8, I will place a larger order to ensure sufficient inventory is available. The arriving delivery of 12 units in this round will help replenish stock, but I need to account for the upstream backlog and the expected spike in demand.
#
# [15]
#
# --------------------------------------------------------------------------------
# UserProxy (to Wholesaler_Agent):
#
# Now this is the round 7, and you are at the stage 2 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 0 unit(s)
#  - Current Backlog (you owing to the downstream): 24 unit(s)
#  - Upstream Backlog (your upstream owing to you): 29 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [12, 0]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [13, 14]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. Your downstream order from the stage 1 for this round is 15. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
#
# --------------------------------------------------------------------------------
# Wholesaler_Agent (to UserProxy):
#
# To address the significant backlog and prepare for the upcoming demand shock, I will place an order to replenish inventory and ensure sufficient stock to meet future demand.
#
# [15]
#
# --------------------------------------------------------------------------------
# UserProxy (to Distributor_Agent):
#
# Now this is the round 7, and you are at the stage 3 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 0 unit(s)
#  - Current Backlog (you owing to the downstream): 29 unit(s)
#  - Upstream Backlog (your upstream owing to you): 77 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [13, 14]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [26, 26]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. Your downstream order from the stage 2 for this round is 15. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
#
# --------------------------------------------------------------------------------
# Distributor_Agent (to UserProxy):
#
# To address the backlog of 29 units and meet the downstream order of 15 units, I need to place a large order to replenish inventory and fulfill the backlog. Considering the lead time of 2 rounds and the temporary demand shock, I will order enough to cover the backlog and the current demand.
#
# [44]
#
# --------------------------------------------------------------------------------
# UserProxy (to Manufacturer_Agent):
#
# Now this is the round 7, and you are at the stage 4 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 3 unit(s)
#  - Current Backlog (you owing to the downstream): 77 unit(s)
#  - Upstream Backlog (your upstream owing to you): 0 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [26, 26]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [43, 43]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. Your downstream order from the stage 3 for this round is 44. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
#
# --------------------------------------------------------------------------------
# Manufacturer_Agent (to UserProxy):
#
# To address the significant backlog of 77 units and meet the downstream order of 44 units, I will order enough to cover the current demand and reduce the backlog. Considering the lead time of 2 rounds and the temporary demand shock, I will order 44 units to ensure sufficient supply and manage the backlog effectively.
#
# [44]
#
# --------------------------------------------------------------------------------
# period = 6, action_dict = {'stage_0': 15, 'stage_1': 15, 'stage_2': 44, 'stage_3': 44}, rewards = {'stage_0': -53, 'stage_1': -81, 'stage_2': -32, 'stage_3': -205}, episode_reward = -1497, api_cost = 0
# ================================================================================
# UserProxy (to Retailer_Agent):
#
# Now this is the round 8, and you are at the stage 1 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 13 unit(s)
#  - Current Backlog (you owing to the downstream): 0 unit(s)
#  - Upstream Backlog (your upstream owing to you): 26 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [5, 5]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [0, 13]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
#
# --------------------------------------------------------------------------------
# Retailer_Agent (to UserProxy):
#
# To meet the increased demand of 13 units in this round and prepare for the next rounds of the demand shock, I will place a larger order to ensure sufficient inventory is maintained. The arriving delivery of 13 units in the next round will help replenish stock.
#
# [13]
#
# --------------------------------------------------------------------------------
# UserProxy (to Wholesaler_Agent):
#
# Now this is the round 8, and you are at the stage 2 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 0 unit(s)
#  - Current Backlog (you owing to the downstream): 26 unit(s)
#  - Upstream Backlog (your upstream owing to you): 20 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [0, 13]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [14, 24]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. Your downstream order from the stage 1 for this round is 13. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
#
# --------------------------------------------------------------------------------
# Wholesaler_Agent (to UserProxy):
#
# To address the significant backlog and prepare for the ongoing demand shock, I will place an order to replenish inventory and ensure sufficient stock to meet future demand.
#
# [13]
#
# --------------------------------------------------------------------------------
# UserProxy (to Distributor_Agent):
#
# Now this is the round 8, and you are at the stage 3 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 2 unit(s)
#  - Current Backlog (you owing to the downstream): 20 unit(s)
#  - Upstream Backlog (your upstream owing to you): 95 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [14, 24]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [26, 26]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. Your downstream order from the stage 2 for this round is 13. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
# --------------------------------------------------------------------------------
# Distributor_Agent (to UserProxy):
#
# To address the backlog of 20 units and meet the downstream order of 13 units, I need to place an order that covers the current demand and replenishes inventory. Considering the lead time of 2 rounds and the temporary demand shock, I will order enough to fulfill the downstream order and maintain a buffer.
#
# [33]
#
# --------------------------------------------------------------------------------
# UserProxy (to Manufacturer_Agent):
#
# Now this is the round 8, and you are at the stage 4 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 20 unit(s)
#  - Current Backlog (you owing to the downstream): 95 unit(s)
#  - Upstream Backlog (your upstream owing to you): 0 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [26, 26]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [43, 44]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. Your downstream order from the stage 3 for this round is 33. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
#
# --------------------------------------------------------------------------------
# Manufacturer_Agent (to UserProxy):
#
# To address the backlog of 95 units and meet the downstream order of 33 units, I will order enough to cover the current demand and reduce the backlog. Considering the lead time of 2 rounds and the temporary demand shock, I will order 33 units to ensure sufficient supply and manage the backlog effectively.
#
# [33]
#
# --------------------------------------------------------------------------------
# period = 7, action_dict = {'stage_0': 13, 'stage_1': 13, 'stage_2': 33, 'stage_3': 33}, rewards = {'stage_0': -5, 'stage_1': -75, 'stage_2': -23, 'stage_3': -174}, episode_reward = -1774, api_cost = 0
# ================================================================================
# UserProxy (to Retailer_Agent):
#
# Now this is the round 9, and you are at the stage 1 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 0 unit(s)
#  - Current Backlog (you owing to the downstream): 0 unit(s)
#  - Upstream Backlog (your upstream owing to you): 25 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [5, 13]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [13, 14]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
#
# --------------------------------------------------------------------------------
# Retailer_Agent (to UserProxy):
#
# To meet the increased demand of 13 units in this round and prepare for the next round of the demand shock, I will place a larger order to ensure sufficient inventory is maintained. The arriving deliveries of 13 and 14 units in the next two rounds will help replenish stock.
#
# [13]
#
# --------------------------------------------------------------------------------
# UserProxy (to Wholesaler_Agent):
#
# Now this is the round 9, and you are at the stage 2 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 0 unit(s)
#  - Current Backlog (you owing to the downstream): 25 unit(s)
#  - Upstream Backlog (your upstream owing to you): 9 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [13, 14]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [24, 24]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. Your downstream order from the stage 1 for this round is 13. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
#
# --------------------------------------------------------------------------------
# Wholesaler_Agent (to UserProxy):
#
# To address the significant backlog and prepare for the ongoing demand shock, I will place an order to replenish inventory and ensure sufficient stock to meet future demand.
#
# [13]
#
# --------------------------------------------------------------------------------
# UserProxy (to Distributor_Agent):
#
# Now this is the round 9, and you are at the stage 3 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 4 unit(s)
#  - Current Backlog (you owing to the downstream): 9 unit(s)
#  - Upstream Backlog (your upstream owing to you): 102 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [24, 24]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [26, 26]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. Your downstream order from the stage 2 for this round is 13. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
#
# --------------------------------------------------------------------------------
# Distributor_Agent (to UserProxy):
#
# To address the backlog of 9 units and meet the downstream order of 13 units, I need to place an order that covers the current demand and replenishes inventory. Considering the lead time of 2 rounds and the temporary demand shock, I will order enough to fulfill the downstream order and maintain a buffer.
#
# [22]
#
# --------------------------------------------------------------------------------
# UserProxy (to Manufacturer_Agent):
#
# Now this is the round 9, and you are at the stage 4 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 37 unit(s)
#  - Current Backlog (you owing to the downstream): 102 unit(s)
#  - Upstream Backlog (your upstream owing to you): 0 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [26, 26]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [44, 33]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. Your downstream order from the stage 3 for this round is 22. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
#
# --------------------------------------------------------------------------------
# Manufacturer_Agent (to UserProxy):
#
# To address the backlog of 102 units and meet the downstream order of 22 units, I will order enough to cover the current demand and reduce the backlog. Considering the lead time of 2 rounds and the temporary demand shock, I will order 22 units to ensure sufficient supply and manage the backlog effectively.
#
# [22]
#
# --------------------------------------------------------------------------------
# period = 8, action_dict = {'stage_0': 13, 'stage_1': 13, 'stage_2': 22, 'stage_3': 22}, rewards = {'stage_0': -45, 'stage_1': -18, 'stage_2': -28, 'stage_3': -133}, episode_reward = -1998, api_cost = 0
# ================================================================================
# UserProxy (to Retailer_Agent):
#
# Now this is the round 10, and you are at the stage 1 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 0 unit(s)
#  - Current Backlog (you owing to the downstream): 0 unit(s)
#  - Upstream Backlog (your upstream owing to you): 16 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [13, 13]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [14, 22]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
# --------------------------------------------------------------------------------
# Retailer_Agent (to UserProxy):
#
# To meet the increased demand of 13 units in this final round of the demand shock and prepare for the return to normal demand, I will place a moderate order to replenish inventory. The arriving deliveries of 14 and 22 units in the next two rounds will help rebuild stock levels.
#
# [10]
#
# --------------------------------------------------------------------------------
# UserProxy (to Wholesaler_Agent):
#
# Now this is the round 10, and you are at the stage 2 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 2 unit(s)
#  - Current Backlog (you owing to the downstream): 16 unit(s)
#  - Upstream Backlog (your upstream owing to you): 0 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [14, 22]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [24, 22]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. Your downstream order from the stage 1 for this round is 10. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
#
# --------------------------------------------------------------------------------
# Wholesaler_Agent (to UserProxy):
#
# To address the remaining backlog and prepare for the return to normal demand levels, I will place an order to replenish inventory and ensure sufficient stock to meet future demand.
#
# [10]
#
# --------------------------------------------------------------------------------
# UserProxy (to Distributor_Agent):
#
# Now this is the round 10, and you are at the stage 3 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 8 unit(s)
#  - Current Backlog (you owing to the downstream): 0 unit(s)
#  - Upstream Backlog (your upstream owing to you): 98 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [24, 22]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [26, 26]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. Your downstream order from the stage 2 for this round is 10. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
#
# --------------------------------------------------------------------------------
# Distributor_Agent (to UserProxy):
#
# To maintain sufficient inventory and meet the downstream order of 10 units, I will place an order that covers the current demand and replenishes inventory. Considering the lead time of 2 rounds and the temporary demand shock, I will order enough to fulfill the downstream order and maintain a buffer.
#
# [10]
#
# --------------------------------------------------------------------------------
# UserProxy (to Manufacturer_Agent):
#
# Now this is the round 10, and you are at the stage 4 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 55 unit(s)
#  - Current Backlog (you owing to the downstream): 98 unit(s)
#  - Upstream Backlog (your upstream owing to you): 0 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [26, 26]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [33, 22]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. Your downstream order from the stage 3 for this round is 10. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
#
# --------------------------------------------------------------------------------
# Manufacturer_Agent (to UserProxy):
#
# To address the backlog of 98 units and meet the downstream order of 10 units, I will order enough to cover the current demand and reduce the backlog. Considering the lead time of 2 rounds and the temporary demand shock, I will order 10 units to ensure sufficient supply and manage the backlog effectively.
#
# [10]
#
# --------------------------------------------------------------------------------
# period = 9, action_dict = {'stage_0': 10, 'stage_1': 10, 'stage_2': 10, 'stage_3': 10}, rewards = {'stage_0': -46, 'stage_1': 52, 'stage_2': -104, 'stage_3': -64}, episode_reward = -2160, api_cost = 0
# ================================================================================
# UserProxy (to Retailer_Agent):
#
# Now this is the round 11, and you are at the stage 1 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 1 unit(s)
#  - Current Backlog (you owing to the downstream): 0 unit(s)
#  - Upstream Backlog (your upstream owing to you): 4 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [13, 13]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [22, 22]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
#
# --------------------------------------------------------------------------------
# Retailer_Agent (to UserProxy):
#
# To return to normal inventory levels after the demand shock and account for the arriving deliveries of 22 units in the next two rounds, I will place a smaller order to stabilize stock without over-ordering.
#
# [5]
#
# --------------------------------------------------------------------------------
# UserProxy (to Wholesaler_Agent):
#
# Now this is the round 11, and you are at the stage 2 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 4 unit(s)
#  - Current Backlog (you owing to the downstream): 4 unit(s)
#  - Upstream Backlog (your upstream owing to you): 0 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [22, 22]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [22, 10]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. Your downstream order from the stage 1 for this round is 5. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
#
# --------------------------------------------------------------------------------
# Wholesaler_Agent (to UserProxy):
#
# To address the remaining backlog and prepare for the return to normal demand levels, I will place an order to replenish inventory and ensure sufficient stock to meet future demand.
#
# [5]
#
# --------------------------------------------------------------------------------
# UserProxy (to Distributor_Agent):
#
# Now this is the round 11, and you are at the stage 3 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 24 unit(s)
#  - Current Backlog (you owing to the downstream): 0 unit(s)
#  - Upstream Backlog (your upstream owing to you): 82 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [22, 10]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [26, 26]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. Your downstream order from the stage 2 for this round is 5. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
# --------------------------------------------------------------------------------
# Distributor_Agent (to UserProxy):
#
# To maintain sufficient inventory and meet the downstream order of 5 units, I will place an order that covers the current demand and replenishes inventory. Considering the lead time of 2 rounds and the temporary demand shock, I will order enough to fulfill the downstream order and maintain a buffer.
#
# [5]
#
# --------------------------------------------------------------------------------
# UserProxy (to Manufacturer_Agent):
#
# Now this is the round 11, and you are at the stage 4 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 62 unit(s)
#  - Current Backlog (you owing to the downstream): 82 unit(s)
#  - Upstream Backlog (your upstream owing to you): 0 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [26, 26]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [22, 10]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. Your downstream order from the stage 3 for this round is 5. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
#
# --------------------------------------------------------------------------------
# Manufacturer_Agent (to UserProxy):
#
# To address the backlog of 82 units and meet the downstream order of 5 units, I will order enough to cover the current demand and reduce the backlog. Considering the lead time of 2 rounds and the temporary demand shock, I will order 5 units to ensure sufficient supply and manage the backlog effectively.
#
# [5]
#
# --------------------------------------------------------------------------------
# period = 10, action_dict = {'stage_0': 5, 'stage_1': 5, 'stage_2': 5, 'stage_3': 5}, rewards = {'stage_0': -38, 'stage_1': 3, 'stage_2': -150, 'stage_3': -14}, episode_reward = -2359, api_cost = 0
# ================================================================================
# UserProxy (to Retailer_Agent):
#
# Now this is the round 12, and you are at the stage 1 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 18 unit(s)
#  - Current Backlog (you owing to the downstream): 0 unit(s)
#  - Upstream Backlog (your upstream owing to you): 0 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [13, 5]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [22, 9]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
#
# --------------------------------------------------------------------------------
# Retailer_Agent (to UserProxy):
#
# To maintain stable inventory levels and account for the arriving deliveries of 22 and 9 units in the next two rounds, I will place a smaller order to avoid overstocking while ensuring sufficient stock for normal demand.
#
# [5]
#
# --------------------------------------------------------------------------------
# UserProxy (to Wholesaler_Agent):
#
# Now this is the round 12, and you are at the stage 2 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 17 unit(s)
#  - Current Backlog (you owing to the downstream): 0 unit(s)
#  - Upstream Backlog (your upstream owing to you): 0 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [22, 9]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [10, 5]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. Your downstream order from the stage 1 for this round is 5. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
#
# --------------------------------------------------------------------------------
# Wholesaler_Agent (to UserProxy):
#
# To maintain inventory levels and prepare for the return to normal demand levels, I will place an order to replenish stock and ensure sufficient inventory to meet future demand.
#
# [5]
#
# --------------------------------------------------------------------------------
# UserProxy (to Distributor_Agent):
#
# Now this is the round 12, and you are at the stage 3 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 45 unit(s)
#  - Current Backlog (you owing to the downstream): 0 unit(s)
#  - Upstream Backlog (your upstream owing to you): 61 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [10, 5]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [26, 26]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. Your downstream order from the stage 2 for this round is 5. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
#
# --------------------------------------------------------------------------------
# Distributor_Agent (to UserProxy):
#
# To maintain sufficient inventory and meet the downstream order of 5 units, I will place an order that covers the current demand and replenishes inventory. Considering the lead time of 2 rounds and the temporary demand shock, I will order enough to fulfill the downstream order and maintain a buffer.
#
# [5]
#
# --------------------------------------------------------------------------------
# UserProxy (to Manufacturer_Agent):
#
# Now this is the round 12, and you are at the stage 4 of 4 in the supply chain. Given your current state:
#  - Lead Time: 2 round(s)
#  - Inventory Level: 58 unit(s)
#  - Current Backlog (you owing to the downstream): 61 unit(s)
#  - Upstream Backlog (your upstream owing to you): 0 unit(s)
#  - Previous Sales (in the recent round(s), from old to new): [26, 26]
#  - Arriving Deliveries (in this and the next round(s), from near to far): [10, 5]
#
# The expected demand at the retailer (stage 1) is is normally 5, but it jumps by 8 units to 13 during periods 8 through 10,capturing a temporary demand shock. Your downstream order from the stage 3 for this round is 5. What is your action (order quantity) for this round?
#
# Please state your reason in 1-2 sentences first and then provide your action as a non-negative integer within brackets (e.g. [0]).
#
# --------------------------------------------------------------------------------
# Manufacturer_Agent (to UserProxy):
#
# To address the backlog of 61 units and meet the downstream order of 5 units, I will order enough to cover the current demand and reduce the backlog. Considering the lead time of 2 rounds and the temporary demand shock, I will order 5 units to ensure sufficient supply and manage the backlog effectively.
#
# [5]
#
# --------------------------------------------------------------------------------
# 100%|██████████| 1/1 [00:01<00:00,  1.41s/it]
# period = 11, action_dict = {'stage_0': 5, 'stage_1': 5, 'stage_2': 5, 'stage_3': 5}, rewards = {'stage_0': -35, 'stage_1': -22, 'stage_2': -171, 'stage_3': 23}, episode_reward = -2564, api_cost = 0
# ================================================================================
# rewards = [-2564]
# Rewards: [-2564]
# Mean Episode Reward: -2564.0
# Standard Deviation of Episode Reward: 0.0
